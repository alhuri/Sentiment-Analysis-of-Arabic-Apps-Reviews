# %%
#Imports
import pandas as pd
import numpy as np
import missingno as msno
import re

# %%
#load Dataset
df=pd.read_csv('../data/apps_ar_reviews_dataset.csv')

# Print Shape of dataset
print('Shape of dataset ',df.shape)
# Print Columns
print(df.columns)
# Print dataframe
df
# Out:
# Shape of dataset  (51766, 13)
# Index(['UserName', 'Review', 'Score', 'Date/Time', 'thumbsUp', 'Version',
#        'app', 'lan_review', 'firstName', 'Gender', 'ReviewLength',
#        'words_count', 'Polarity sentiment'],
#       dtype='object')
#                UserName                                             Review  \
# 0          نواف الحربي    تحميلك للتطبيق حتى لو بالخطأ يدخلك في عزل لمد...
# 1        ahmed ghazala    لا يعمل ولا يستجيب في مرحلة التسجيل لايتم ارس...
# 2         ELSyed Attia    للأسف تطبيق سيئ جداً بقالي يومين بحاول اسجل و...
# 3          انور القدسي    ما قدرت اسجل في التطبيق ، اوصل ل آخر خطوه وهي...
# 4           اسلام سعيد    نزلت البرنامج اكثر من مره وسجلت بياناتي كلها ...
# ...                 ...                                                ...
# 51761  عبدالله الأسمري                                              ممتاز
# 51762        خالد عقيل                                              ممتاز
# 51763    عبدالله عتودي                                              ممتاز
# 51764   خوالي تاج راسي                                                 Ok
# 51765         محمد علي                                             ممتازة
#
#        Score              Date/Time  thumbsUp Version      app  lan_review  \
# 0          1   2021-01-27 08:41:10          1     1.7  tetaman      Arabic
# 1          1   2021-01-23 21:49:16          0     1.7  tetaman      Arabic
# 2          1   2021-01-23 00:51:06          1     1.7  tetaman      Arabic
# 3          1   2021-01-21 23:55:30          0    None  tetaman      Arabic
# 4          1   2021-01-21 15:25:36          0     1.7  tetaman      Arabic
# ...      ...                    ...       ...     ...      ...         ...
# 51761      5   2019-09-25 12:49:11          2       1  sehhaty  Non-Arabic
# 51762      5   2019-09-24 18:03:41          1       1  sehhaty  Non-Arabic
# 51763      5   2019-09-23 19:49:51          1       1  sehhaty  Non-Arabic
# 51764      5   2019-09-23 18:50:00          0       1  sehhaty  Non-Arabic
# 51765      5   2019-09-19 18:47:00          1       1  sehhaty      Arabic
#
#       firstName Gender  ReviewLength  words_count Polarity sentiment
# 0          نواف   Male           164           31            neutral
# 1         ahmed   Male            55           10            neutral
# 2        ELSyed   Male            67           12           negative
# 3          انور   Male            89           19            neutral
# 4         اسلام   Male           248           44            neutral
# ...         ...    ...           ...          ...                ...
# 51761   عبدالله   Male             7            1           positive
# 51762      خالد   Male             7            1           positive
# 51763   عبدالله   Male             7            1           positive
# 51764     خوالي   Male             4            1           negative
# 51765      محمد   Male             8            1           positive
#
# [51766 rows x 13 columns]

# %%
# Summary about the dataframe 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51766 entries, 0 to 51765
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   UserName            51766 non-null  object
#  1   Review              51766 non-null  object
#  2   Score               51766 non-null  int64
#  3   Date/Time           51766 non-null  object
#  4   thumbsUp            51766 non-null  int64
#  5   Version             51766 non-null  object
#  6   app                 51766 non-null  object
#  7   lan_review          51766 non-null  object
#  8   firstName           51766 non-null  object
#  9   Gender              51766 non-null  object
#  10  ReviewLength        51766 non-null  int64
#  11  words_count         51766 non-null  int64
#  12  Polarity sentiment  51766 non-null  object
# dtypes: int64(4), object(9)
# memory usage: 5.1+ MB

# %% [markdown]
# ## Cleaning

# %%
#pip install PyArabic

# %%
import re 
def cleaning(text):
    
 Arabic_numbers = ['٤','١','٢','٣','٥','٦','٧','٨','٩','٠']
 special_character = ['؟','،','?',',','!','.',':','"','""','‘‘','‘','؛','↓',"'", '‰',
                      '`','€',';','ç','ı','À','@','٬','~᷂','٫','⁩◕','.',
                      '=','#','$','%','^','&','*','()',')','(','\\','/',
                      '((', '_', '"','"', '…','-','×','ツ','+','%','٪','⁩ლ']

#remove emojis
 text= remove_emoji(text)
    
#replace special characters with whitespaces 
 for word in range(0, len(special_character)):
     text = text.replace(special_character[word], ' ') 
              
#replace  arabic numbers with whitespaces 
 for word in range(0, len(Arabic_numbers)):
     text = text.replace(Arabic_numbers[word], ' ') 
    
#remove english words letters and numbers
 text = re.sub(r'[0-9a-zA-Z]+',' ', text)

 return text

# %%
import emoji
def remove_emoji(text):
    return emoji.demojize(text)

# %% [markdown]
# ## Preprocessing

# %%
# tokenize to remove stopwords and join into sentences again
from nltk.corpus import stopwords
import pyarabic.araby as araby
def stop_word_removal(text):
 stop_words = set(stopwords.words("arabic"))
 words = araby.tokenize(text)
 text = " ".join([w for w in words if not w in stop_words])
 return text

# %%
import pyarabic.araby as araby
def normalization(text):
#replace Ta'a and Hamza'a and Ya'a
 text = re.sub("[إأٱآا]", "ا", text)
 text = re.sub("ى", "ي", text)
 text = re.sub("ة", "ه", text)
#remove extra whitespace
 text = re.sub('\s+', ' ', text)   
#remove tashkeel
 text = araby.strip_tashkeel(text)
 return text

# %%
def pre_processing(text):
#Normalization 
 text = normalization(text)
#stop words removal
 text = stop_word_removal(text)
#Cleaning
 text = cleaning(text)
 return text

# %%
#pre_processing the review column
df['Review'] = df['Review'].apply(lambda x:pre_processing(x))
df
# Out:
#                UserName                                             Review  \
# 0          نواف الحربي   تحميلك للتطبيق حتي بالخطا يدخلك عزل لمده    يو...
# 1        ahmed ghazala         يعمل يستجيب مرحله التسجيل لايتم ارسال الكود
# 2         ELSyed Attia   للاسف تطبيق سيئ جدا بقالي يومين بحاول اسجل يرس...
# 3          انور القدسي   قدرت اسجل التطبيق   اوصل اخر خطوه وهي كود التح...
# 4           اسلام سعيد   نزلت البرنامج اكثر مره وسجلت بياناتي كلها لاني...
# ...                 ...                                                ...
# 51761  عبدالله الأسمري                                               ممتاز
# 51762        خالد عقيل                                               ممتاز
# 51763    عبدالله عتودي                                               ممتاز
# 51764   خوالي تاج راسي
# 51765         محمد علي                                              ممتازه
#
#        Score              Date/Time  thumbsUp Version      app  lan_review  \
# 0          1   2021-01-27 08:41:10          1     1.7  tetaman      Arabic
# 1          1   2021-01-23 21:49:16          0     1.7  tetaman      Arabic
# 2          1   2021-01-23 00:51:06          1     1.7  tetaman      Arabic
# 3          1   2021-01-21 23:55:30          0    None  tetaman      Arabic
# 4          1   2021-01-21 15:25:36          0     1.7  tetaman      Arabic
# ...      ...                    ...       ...     ...      ...         ...
# 51761      5   2019-09-25 12:49:11          2       1  sehhaty  Non-Arabic
# 51762      5   2019-09-24 18:03:41          1       1  sehhaty  Non-Arabic
# 51763      5   2019-09-23 19:49:51          1       1  sehhaty  Non-Arabic
# 51764      5   2019-09-23 18:50:00          0       1  sehhaty  Non-Arabic
# 51765      5   2019-09-19 18:47:00          1       1  sehhaty      Arabic
#
#       firstName Gender  ReviewLength  words_count Polarity sentiment
# 0          نواف   Male           164           31            neutral
# 1         ahmed   Male            55           10            neutral
# 2        ELSyed   Male            67           12           negative
# 3          انور   Male            89           19            neutral
# 4         اسلام   Male           248           44            neutral
# ...         ...    ...           ...          ...                ...
# 51761   عبدالله   Male             7            1           positive
# 51762      خالد   Male             7            1           positive
# 51763   عبدالله   Male             7            1           positive
# 51764     خوالي   Male             4            1           negative
# 51765      محمد   Male             8            1           positive
#
# [51766 rows x 13 columns]

# %% [markdown]
# ### Remove Reviews Without Sentiment

# %%
df["Polarity sentiment"].value_counts()
# Out:
# positive                 39132
# negative                  9327
# neutral                   3293
# No_sentment_extracted       14
# Name: Polarity sentiment, dtype: int64

# %%
df = df.drop(df[df['Polarity sentiment'] == "No_sentment_extracted"].index)

# %% [markdown]
# ### Remove Non Arabic Reviews

# %%
#count of non arabic reviews
df["lan_review"].value_counts()
# Out:
# Arabic        30566
# Non-Arabic    21186
# Name: lan_review, dtype: int64

# %%
# drop non arabic reviews
df = df.drop(df[df['lan_review'] == "Non-Arabic"].index)
df["lan_review"].value_counts()
# Out:
# Arabic    30566
# Name: lan_review, dtype: int64

# %% [markdown]
# ### Extra cleaning

# %%
#remove punctuation 
p = re.compile(r'[^\w\s]+')
df['Review'] = [p.sub('', x) for x in df['Review'].tolist()]

#remove tabs and new lines from the text 
df['Review'] = df.Review.str.replace("\xa0"," ") 
df['Review'] = df.Review.str.replace("\n"," ")
df['Review'] = df['Review'].replace("\t"," ", regex=True)

# %%
# check for nulls 
df['Review'].isnull().sum()
# Out:
# 0

# %%
#remove blanks by replacing them with Nan
df['Review'].replace(r'^\s*$', np.nan, regex=True,inplace=True)

# %%
# check for nulls 
df['Review'].isnull().sum()
# Out:
# 84

# %%
# drop nans
df.dropna(subset=['Review'], inplace=True)
# drop duplicates 
df=df.drop_duplicates(subset=['Review'])

# %%
df
# Out:
#                       UserName  \
# 0                 نواف الحربي
# 1               ahmed ghazala
# 2                ELSyed Attia
# 3                 انور القدسي
# 4                  اسلام سعيد
# ...                        ...
# 51736        محمد ابو ابراهيم
# 51741                a-_-33 m
# 51745           ريما المحيميد
# 51746  استغفر الله سبحان الله
# 51756           منوعات يوتيوب
#
#                                                   Review  Score  \
# 0      تحميلك للتطبيق حتي بالخطا يدخلك عزل لمده    يو...      1
# 1            يعمل يستجيب مرحله التسجيل لايتم ارسال الكود      1
# 2      للاسف تطبيق سيئ جدا بقالي يومين بحاول اسجل يرس...      1
# 3      قدرت اسجل التطبيق   اوصل اخر خطوه وهي كود التح...      1
# 4      نزلت البرنامج اكثر مره وسجلت بياناتي كلها لاني...      1
# ...                                                  ...    ...
# 51736                                             تجريبي      5
# 51741                             كانت تجربه سهله وميسره      5
# 51745  برنامج جيد جدا واجهت مشكله فتحه الكمبيوتر وايض...      5
# 51746                                 اطبع التقرير الطبي      5
# 51756  السلام عليكم    البرنامج وبكل امانه وصدق ممتاز...      5
#
#                    Date/Time  thumbsUp Version      app lan_review firstName  \
# 0       2021-01-27 08:41:10          1     1.7  tetaman     Arabic      نواف
# 1       2021-01-23 21:49:16          0     1.7  tetaman     Arabic     ahmed
# 2       2021-01-23 00:51:06          1     1.7  tetaman     Arabic    ELSyed
# 3       2021-01-21 23:55:30          0    None  tetaman     Arabic      انور
# 4       2021-01-21 15:25:36          0     1.7  tetaman     Arabic     اسلام
# ...                      ...       ...     ...      ...        ...       ...
# 51736   2019-10-30 13:15:57          0   1.1.0  sehhaty     Arabic      محمد
# 51741   2019-10-21 11:00:28          0       1  sehhaty     Arabic    a-_-33
# 51745   2019-10-20 01:35:25          1       1  sehhaty     Arabic      ريما
# 51746   2019-10-16 12:54:24          0       1  sehhaty     Arabic    استغفر
# 51756   2019-10-02 08:50:52         56       1  sehhaty     Arabic    منوعات
#
#           Gender  ReviewLength  words_count Polarity sentiment
# 0           Male           164           31            neutral
# 1           Male            55           10            neutral
# 2           Male            67           12           negative
# 3           Male            89           19            neutral
# 4           Male           248           44            neutral
# ...          ...           ...          ...                ...
# 51736       Male             8            1           negative
# 51741  Not_found            24            4           positive
# 51745     Female           103           18           positive
# 51746  Not_found            24            4            neutral
# 51756  Not_found           283           48           positive
#
# [21474 rows x 13 columns]

# %%
#write the dataframe into csv file
df.to_csv('../data/Clean_apps_ar_reviews.csv',index=False)
