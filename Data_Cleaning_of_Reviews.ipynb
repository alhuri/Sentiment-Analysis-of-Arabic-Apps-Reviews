# %%
#Imports
import pandas as pd
import numpy as np
import missingno as msno
import re

# %%
#pip install missingno

# %%
#load Dataset
df=pd.read_csv('apps_ar_reviews_dataset.csv')

# Print Shape of dataset
print('Shape of dataset ',df.shape)
# Print Columns
print(df.columns)
# Print dataframe
df
# Out:
# Shape of dataset  (51766, 13)
# Index(['UserName', 'Review', 'Score', 'Date/Time', 'thumbsUp', 'Version',
#        'app', 'lan_review', 'firstName', 'Gender', 'ReviewLength',
#        'words_count', 'Polarity sentiment'],
#       dtype='object')
#              UserName                                             Review  \
# 0           Yaser Co    الله يحفظ الملك سلمان وولي عهده الامير محمد و...
# 1       ابراهيم هزام                                                  👍
# 2        نواف الحربي    تحميلك للتطبيق حتى لو بالخطأ يدخلك في عزل لمد...
# 3      ahmed ghazala    لا يعمل ولا يستجيب في مرحلة التسجيل لايتم ارس...
# 4       ELSyed Attia    للأسف تطبيق سيئ جداً بقالي يومين بحاول اسجل و...
# ...               ...                                                ...
# 51761    Hussein Ali    التطبيق مهم ياريت تربطون الدخول له بنفس بيانا...
# 51762       محمد علي                                             ممتازة
# 51763    محمد الشريف    تجربة سيئة وتطبيق غبي لم أستطيع عمل التسجيل ا...
# 51764       Ali Aziz    فيه مشاكل لا استطيع اختيار المركز ابي اطلع ال...
# 51765          yh ha    تطبيق فاشل ليست كل المدن موجوده والا الأحياء ...
#
#        Score              Date/Time  thumbsUp Version      app  lan_review  \
# 0          5   2021-01-31 16:01:09          0     1.7  tetaman      Arabic
# 1          5   2021-01-30 06:34:13          0     1.7  tetaman  Non-Arabic
# 2          1   2021-01-27 08:41:10          1     1.7  tetaman      Arabic
# 3          1   2021-01-23 21:49:16          0     1.7  tetaman      Arabic
# 4          1   2021-01-23 00:51:06          1     1.7  tetaman      Arabic
# ...      ...                    ...       ...     ...      ...         ...
# 51761      2   2019-09-20 05:32:58         67       1  sehhaty      Arabic
# 51762      5   2019-09-19 18:47:00          1       1  sehhaty      Arabic
# 51763      1   2019-09-19 16:39:09         14       1  sehhaty      Arabic
# 51764      2   2019-09-19 16:21:43          7       1  sehhaty      Arabic
# 51765      1   2019-09-19 00:37:20          4       1  sehhaty      Arabic
#
#       firstName     Gender  ReviewLength  words_count Polarity sentiment
# 0         Yaser       Male           109           16           positive
# 1       ابراهيم       Male             3            1           positive
# 2          نواف       Male           164           31            neutral
# 3         ahmed       Male            55           10            neutral
# 4        ELSyed       Male            67           12           negative
# ...         ...        ...           ...          ...                ...
# 51761   Hussein       Male           103           17            neutral
# 51762      محمد       Male             8            1           positive
# 51763      محمد       Male            52            9           negative
# 51764       Ali       Male            79           14           negative
# 51765        yh  Not_found            52            9           negative
#
# [51766 rows x 13 columns]

# %%
# Summary about the dataframe 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51766 entries, 0 to 51765
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   UserName            51766 non-null  object
#  1   Review              51766 non-null  object
#  2   Score               51766 non-null  int64
#  3   Date/Time           51766 non-null  object
#  4   thumbsUp            51766 non-null  int64
#  5   Version             51766 non-null  object
#  6   app                 51766 non-null  object
#  7   lan_review          51766 non-null  object
#  8   firstName           51766 non-null  object
#  9   Gender              51766 non-null  object
#  10  ReviewLength        51766 non-null  int64
#  11  words_count         51766 non-null  int64
#  12  Polarity sentiment  51766 non-null  object
# dtypes: int64(4), object(9)
# memory usage: 5.1+ MB

# %% [markdown]
# ## Cleaning

# %%
#pip install PyArabic

# %%
# tokenize to remove stopwords and join into sentences again
from nltk.corpus import stopwords
import pyarabic.araby as araby
def stop_word_removal(text):
 stop_words = set(stopwords.words("arabic"))
 words = araby.tokenize(text)
 text = " ".join([w for w in words if not w in stop_words])
 return text

# %%
import re 
def cleaning(text):
    
 Arabic_numbers = ['٤','١','٢','٣','٥','٦','٧','٨','٩','٠']
 special_character = ['؟','،','?',',','!','.',':','"','""','‘‘','‘','؛','↓',"'", '‰',
                      '`','€',';','ç','ı','À','@','٬','~᷂','٫','⁩◕','.',
                      '=','#','$','%','^','&','*','()',')','(','\\','/',
                      '((', '_', '"','"', '…','-','×','ツ','+','%','٪','⁩ლ']

#remove emojis
 text= remove_emoji(text)
    
#replace special characters with whitespaces 
 for word in range(0, len(special_character)):
     text = text.replace(special_character[word], ' ') 
              
#replace  arabic numbers with whitespaces 
 for word in range(0, len(Arabic_numbers)):
     text = text.replace(Arabic_numbers[word], ' ') 
    
#remove english words letters and numbers
 text = re.sub(r'[0-9a-zA-Z]+',' ', text)

 return text

# %%
#pip install emoji

# %%
import emoji
def remove_emoji(text):
    return emoji.demojize(text)

# %%
import pyarabic.araby as araby
def normalization(text):
#replace Ta'a and Hamza'a and Ya'a
 text = re.sub("[إأٱآا]", "ا", text)
 text = re.sub("ى", "ي", text)
 text = re.sub("ة", "ه", text)
#remove extra whitespace
 text = re.sub('\s+', ' ', text)   
#remove tashkeel
 text = araby.strip_tashkeel(text)
#remove tatweel
 text = araby.strip_tatweel(text)
 return text

# %%
def pre_processing(text):
#Normalization 
 text = normalization(text)
#stop words removal
 text = stop_word_removal(text)
#Cleaning
 text = cleaning(text)
 return text

# %%
#pre_processing the review column
df['Review'] = df['Review'].apply(lambda x:pre_processing(x))
df
# Out:
#              UserName                                             Review  \
# 0           Yaser Co   الله يحفظ الملك سلمان وولي عهده الامير محمد وا...
# 1       ابراهيم هزام
# 2        نواف الحربي   تحميلك للتطبيق حتي بالخطا يدخلك عزل لمده    يو...
# 3      ahmed ghazala         يعمل يستجيب مرحله التسجيل لايتم ارسال الكود
# 4       ELSyed Attia   للاسف تطبيق سيئ جدا بقالي يومين بحاول اسجل يرس...
# ...               ...                                                ...
# 51761    Hussein Ali   التطبيق مهم ياريت تربطون الدخول بنفس بيانات ال...
# 51762       محمد علي                                              ممتازه
# 51763    محمد الشريف     تجربه سيئه وتطبيق غبي استطيع عمل التسجيل الجديد
# 51764       Ali Aziz   مشاكل استطيع اختيار المركز ابي اطلع الاجازه قد...
# 51765          yh ha          تطبيق فاشل المدن موجوده والا الاحياء واضحه
#
#        Score              Date/Time  thumbsUp Version      app  lan_review  \
# 0          5   2021-01-31 16:01:09          0     1.7  tetaman      Arabic
# 1          5   2021-01-30 06:34:13          0     1.7  tetaman  Non-Arabic
# 2          1   2021-01-27 08:41:10          1     1.7  tetaman      Arabic
# 3          1   2021-01-23 21:49:16          0     1.7  tetaman      Arabic
# 4          1   2021-01-23 00:51:06          1     1.7  tetaman      Arabic
# ...      ...                    ...       ...     ...      ...         ...
# 51761      2   2019-09-20 05:32:58         67       1  sehhaty      Arabic
# 51762      5   2019-09-19 18:47:00          1       1  sehhaty      Arabic
# 51763      1   2019-09-19 16:39:09         14       1  sehhaty      Arabic
# 51764      2   2019-09-19 16:21:43          7       1  sehhaty      Arabic
# 51765      1   2019-09-19 00:37:20          4       1  sehhaty      Arabic
#
#       firstName     Gender  ReviewLength  words_count Polarity sentiment
# 0         Yaser       Male           109           16           positive
# 1       ابراهيم       Male             3            1           positive
# 2          نواف       Male           164           31            neutral
# 3         ahmed       Male            55           10            neutral
# 4        ELSyed       Male            67           12           negative
# ...         ...        ...           ...          ...                ...
# 51761   Hussein       Male           103           17            neutral
# 51762      محمد       Male             8            1           positive
# 51763      محمد       Male            52            9           negative
# 51764       Ali       Male            79           14           negative
# 51765        yh  Not_found            52            9           negative
#
# [51766 rows x 13 columns]

# %% [markdown]
# ### Extra cleaning

# %%
#remove punctuation 
p = re.compile(r'[^\w\s]+')
df['Review'] = [p.sub('', x) for x in df['Review'].tolist()]

#remove harakat, tabs, new lines from the text 
df['Review'] = df.Review.str.replace("\xa0"," ") 
df['Review'] = df.Review.str.replace("\n"," ")
df['Review'] = df['Review'].replace("\t"," ", regex=True)
df['Review'] = df['Review'].replace("ًٌٍَُِّْ"," ", regex=True)
df['Review'] = df['Review'].replace("ًٌٍَُِّْ"," ", regex=True)

# %%
# check for nulls 
df['Review'].isnull().sum()
# Out:
# 0

# %%
#remove blanks by replacing them with Nan
df['Review'].replace(r'^\s*$', np.nan, regex=True,inplace=True)

# %%
# check for nulls 
df['Review'].isnull().sum()
# Out:
# 1959

# %%
# drop nans
df.dropna(subset=['Review'], inplace=True)
# drop duplicates 
df = df.drop_duplicates()

# %%
df
# Out:
#              UserName                                             Review  \
# 0           Yaser Co   الله يحفظ الملك سلمان وولي عهده الامير محمد وا...
# 2        نواف الحربي   تحميلك للتطبيق حتي بالخطا يدخلك عزل لمده    يو...
# 3      ahmed ghazala         يعمل يستجيب مرحله التسجيل لايتم ارسال الكود
# 4       ELSyed Attia   للاسف تطبيق سيئ جدا بقالي يومين بحاول اسجل يرس...
# 5          ماجد غازي                                                زينه
# ...               ...                                                ...
# 51761    Hussein Ali   التطبيق مهم ياريت تربطون الدخول بنفس بيانات ال...
# 51762       محمد علي                                              ممتازه
# 51763    محمد الشريف     تجربه سيئه وتطبيق غبي استطيع عمل التسجيل الجديد
# 51764       Ali Aziz   مشاكل استطيع اختيار المركز ابي اطلع الاجازه قد...
# 51765          yh ha          تطبيق فاشل المدن موجوده والا الاحياء واضحه
#
#        Score              Date/Time  thumbsUp Version      app  lan_review  \
# 0          5   2021-01-31 16:01:09          0     1.7  tetaman      Arabic
# 2          1   2021-01-27 08:41:10          1     1.7  tetaman      Arabic
# 3          1   2021-01-23 21:49:16          0     1.7  tetaman      Arabic
# 4          1   2021-01-23 00:51:06          1     1.7  tetaman      Arabic
# 5          5   2021-01-22 12:42:00          0     1.7  tetaman  Non-Arabic
# ...      ...                    ...       ...     ...      ...         ...
# 51761      2   2019-09-20 05:32:58         67       1  sehhaty      Arabic
# 51762      5   2019-09-19 18:47:00          1       1  sehhaty      Arabic
# 51763      1   2019-09-19 16:39:09         14       1  sehhaty      Arabic
# 51764      2   2019-09-19 16:21:43          7       1  sehhaty      Arabic
# 51765      1   2019-09-19 00:37:20          4       1  sehhaty      Arabic
#
#       firstName     Gender  ReviewLength  words_count Polarity sentiment
# 0         Yaser       Male           109           16           positive
# 2          نواف       Male           164           31            neutral
# 3         ahmed       Male            55           10            neutral
# 4        ELSyed       Male            67           12           negative
# 5          ماجد       Male             6            1           negative
# ...         ...        ...           ...          ...                ...
# 51761   Hussein       Male           103           17            neutral
# 51762      محمد       Male             8            1           positive
# 51763      محمد       Male            52            9           negative
# 51764       Ali       Male            79           14           negative
# 51765        yh  Not_found            52            9           negative
#
# [49807 rows x 13 columns]

# %%
#write the dataframe into csv file
df.to_csv('Clean_apps_ar_reviews.csv',index=False)
